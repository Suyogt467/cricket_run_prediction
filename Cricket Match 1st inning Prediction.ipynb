# %%
import pandas as pd
import numpy as np
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('C:\\Users\\ADMIN\\Downloads\\csv datasets\\Cricket\\t20s'):
    filenames.append(os.path.join('C:\\Users\\ADMIN\\Downloads\\csv datasets\\Cricket\\t20s',file))

# %%
filenames[0:5]
# Out:
# ['C:\\Users\\ADMIN\\Downloads\\csv datasets\\Cricket\\t20s\\1001349.yaml',
#  'C:\\Users\\ADMIN\\Downloads\\csv datasets\\Cricket\\t20s\\1001351.yaml',
#  'C:\\Users\\ADMIN\\Downloads\\csv datasets\\Cricket\\t20s\\1001353.yaml',
#  'C:\\Users\\ADMIN\\Downloads\\csv datasets\\Cricket\\t20s\\1004729.yaml',
#  'C:\\Users\\ADMIN\\Downloads\\csv datasets\\Cricket\\t20s\\1007655.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file,'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['Match_id'] = counter
        final_df = final_df.append(df)
        counter+= 1
final_df
# Out:
#   0%|                                                                                         | 0/1433 [00:00<?, ?it/s]C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\1019149722.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|                                                                                 | 1/1433 [00:00<22:02,  1.08it/s]C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\1019149722.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
final_df.head(2)
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
#
#   meta.created  meta.revision    info.dates info.gender info.match_type  \
# 0   2017-02-18              2  [2017-02-17]        male             T20
# 0   2017-02-19              2  [2017-02-19]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  ...  \
# 0                      5.0           Sri Lanka          20  ...
# 0                      2.0           Sri Lanka          20  ...
#
#   info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0                  NaN                    NaN                NaN
# 0                  NaN                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# ...

# %%
backup = final_df.copy()

# %%
final_df.head(3)
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
#
#   meta.created  meta.revision    info.dates info.gender info.match_type  \
# 0   2017-02-18              2  [2017-02-17]        male             T20
# 0   2017-02-19              2  [2017-02-19]        male             T20
# 0   2017-02-23              1  [2017-02-22]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  ...  \
# 0                      5.0           Sri Lanka          20  ...
# 0                      2.0           Sri Lanka          20  ...
# 0                      NaN           Australia          20  ...
#
#   info.outcome.by.runs info.match_type_number info.neutral_venue  \
# ...

# %%
final_df.drop(columns=[
             'meta.data_version',
              'meta.created',
              'meta.revision',
              'info.match_type',
              'info.outcome.bowl_out',
              'info.bowl_out',
              'info.supersubs.South Africa',
              'info.supersubs.New Zealand',
              'info.outcome.eliminator',
              'info.outcome.result',
              'info.outcome.method',
              'info.neutral_venue',
              'info.match_type_number',
              'info.outcome.by.runs',
              'info.outcome.by.wickets'
],inplace = True)

# %%
final_df['info.overs'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'info.overs'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
final_df = final_df[final_df['info.overs'] ==20]
final_df.drop(columns=['info.overs'],inplace=True)
final_df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\854621649.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs'],inplace=True)
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# male      963
# female    466
# Name: info.gender, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace = True)
final_df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\2303069037.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace = True)
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# ...

# %%
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.outcome.winner info.player_of_match  \
# 0            Sri Lanka      [DAS Gunaratne]
# 0            Sri Lanka      [DAS Gunaratne]
# ...

# %%
import pickle
# pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
# matches = pickle.load(open('dataset_level1.pkl','rb'))

# %%
matches.head()
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0  [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
#
#   info.outcome.winner info.player_of_match              info.teams  \
# 0           Sri Lanka      [DAS Gunaratne]  [Australia, Sri Lanka]
# 0           Sri Lanka      [DAS Gunaratne]  [Australia, Sri Lanka]
# 0           Australia            [A Zampa]  [Australia, Sri Lanka]
# 0           Hong Kong                  NaN    [Ireland, Hong Kong]
# 0            Zimbabwe       [E Chigumbura]       [Zimbabwe, India]
#
#   info.toss.decision info.toss.winner              info.umpires  \
# 0              field        Sri Lanka    [MD Martell, P Wilson]
# ...

# %%
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.4: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.5: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {1.1: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
        'match_id' : match_id,
        'teams' :teams,
        'batting_team': batting_team,
        'ball': ball_of_match,
        'batsman' : batsman,
        'bowler' :bowler,
        'runs' : runs,
        'player_dismissed' : player_of_dismissed,
        'city' : city,
        'venue': venue
    })
    delivery_df = delivery_df.append(loop_df)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\2273494709.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\2273494709.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\2273494709.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\2273494709.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# ...

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121       964  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       964  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       964  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       964  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       964  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue
# ...

# %%
#  pickle.dump(delivery_df,open('first_innings_runs_predictions','wb'))

# %%
#Now lets gets this columns Batting_team,Bowling_team,Current_runs,Wickets_left,Current_runrate,City,Bolls_left,Last_five_oves_runs,final_score

# %%
def bowl(row):
    for team in row['teams']:
        if team!= row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121       964  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       964  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       964  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       964  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       964  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue  \
# ...

# %%
# Now we can drop teams
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
final_df.head(3)
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
#
#   info.gender info.outcome.winner  info.overs info.player_of_match  \
# 0        male           Sri Lanka          20      [DAS Gunaratne]
# 0        male           Sri Lanka          20      [DAS Gunaratne]
# 0        male           Australia          20            [A Zampa]
#
#                info.teams info.toss.decision info.toss.winner  \
# 0  [Australia, Sri Lanka]              field        Sri Lanka
# 0  [Australia, Sri Lanka]              field        Sri Lanka
# 0  [Australia, Sri Lanka]              field        Sri Lanka
#
#              info.umpires                      info.venue  Match_id info.city
# 0  [MD Martell, P Wilson]        Melbourne Cricket Ground         1       NaN
# ...

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies', 'Ireland',
#        'Afghanistan', 'Pakistan', 'United Arab Emirates', 'Scotland',
#        'Oman', 'Papua New Guinea', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania'],
#       dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zeland',
    'South Africa',
    'England',
    'West Indies',
    'Sri Lanka',
    'Afghanistan',
    'Pakistan'
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# ...

# %%
# pickle.dump(output,open('clean_dataset_of_cricket_first_inning_prediction','wb'))

# %%
df = delivery_df

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# ball                   0
# batsman                0
# bowler                 0
# runs                   0
# player_dismissed       0
# city                6730
# venue                  0
# bowling_team           0
# dtype: int64

# %%
final_df.head(3)
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
#
#   info.gender info.outcome.winner  info.overs info.player_of_match  \
# 0        male           Sri Lanka          20      [DAS Gunaratne]
# 0        male           Sri Lanka          20      [DAS Gunaratne]
# 0        male           Australia          20            [A Zampa]
#
#                info.teams info.toss.decision info.toss.winner  \
# 0  [Australia, Sri Lanka]              field        Sri Lanka
# 0  [Australia, Sri Lanka]              field        Sri Lanka
# 0  [Australia, Sri Lanka]              field        Sri Lanka
#
#              info.umpires                      info.venue  Match_id info.city
# 0  [MD Martell, P Wilson]        Melbourne Cricket Ground         1       NaN
# ...

# %%
# now for city we can use venue column
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2226
# Melbourne Cricket Ground                   1453
# Pallekele International Cricket Stadium    1239
# Sydney Cricket Ground                       501
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# ball                0
# batsman             0
# bowler              0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# bowling_team        0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed       city bowling_team
# 0                  0  Melbourne    Sri Lanka
# 1                  0  Melbourne    Sri Lanka
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts()>600].index.tolist()

# %%
df[df['city'].isin(eligible_cities)]
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed       city bowling_team
# 0                  0  Melbourne    Sri Lanka
# 1                  0  Melbourne    Sri Lanka
# ...

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed       city bowling_team  current_score
# 0                  0  Melbourne    Sri Lanka              0
# ...

# %%
# Spliting the ball column to get the over and ball separately 
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed       city bowling_team  current_score over ball_no  \
# 0                  0  Melbourne    Sri Lanka              0    0       1
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype(int)
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#      player_dismissed       city bowling_team  current_score over ball_no  \
# 0                   0  Melbourne    Sri Lanka              0    0       1
# ...

# %%
# Current RunRate
df['current_runrate'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#      player_dismissed       city bowling_team  current_score over ball_no  \
# 0                   0  Melbourne    Sri Lanka              0    0       1
# ...

# %%
# Last five over runrate
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\2592540141.py:7: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batsman', 'batting_team', 'bowler', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five

# %%
df.head(1)
# Out:
#    match_id batting_team  ball   batsman      bowler  runs  player_dismissed  \
# 0         2    Australia   0.1  AJ Finch  SL Malinga     0                 0
#
#         city bowling_team  current_score over ball_no  balls_bowled  \
# 0  Melbourne    Sri Lanka              0    0       1             1
#
#    balls_left  wickets_left  current_runrate  last_five
# 0         119            10              0.0        NaN

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on = 'match_id')

# %%
 final_df
# Out:
#        match_id  runs_x batting_team  ball          batsman      bowler  \
# 0             2     168    Australia   0.1         AJ Finch  SL Malinga
# 1             2     168    Australia   0.2         AJ Finch  SL Malinga
# 2             2     168    Australia   0.3         AJ Finch  SL Malinga
# 3             2     168    Australia   0.4        M Klinger  SL Malinga
# 4             2     168    Australia   0.5        M Klinger  SL Malinga
# ...         ...     ...          ...   ...              ...         ...
# 49084       964     128    Sri Lanka  19.3  SMSM Senanayake    MA Starc
# 49085       964     128    Sri Lanka  19.4      DM de Silva    MA Starc
# 49086       964     128    Sri Lanka  19.5      DM de Silva    MA Starc
# 49087       964     128    Sri Lanka  19.6  SMSM Senanayake    MA Starc
# 49088       964     128    Sri Lanka  19.7  SMSM Senanayake    MA Starc
#
#        runs_y  player_dismissed       city bowling_team  current_score over  \
# ...

# %%
final_df = final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','current_runrate','last_five','runs_x']]

# %%
final_df.isnull().sum()
# Out:
# batting_team           0
# bowling_team           0
# city                   0
# current_score          0
# balls_left             0
# wickets_left           0
# current_runrate        0
# last_five          11687
# runs_x                 0
# dtype: int64

# %%
final_df.dropna(inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13016\2709626079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team       0
# bowling_team       0
# city               0
# current_score      0
# balls_left         0
# wickets_left       0
# current_runrate    0
# last_five          0
# runs_x             0
# dtype: int64

# %%
# To avoid the data to be bias we shaffle the data
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team bowling_team        city  current_score  balls_left  \
# 14057   Afghanistan  West Indies     Lucknow            119          17
# 27944      Pakistan      England       Dubai            107          13
# 24576   West Indies    Australia      Sydney             90          29
# 24341      Pakistan    Sri Lanka     Colombo            143          17
# 31394       England  Afghanistan     Colombo            130          25
# ...             ...          ...         ...            ...         ...
# 5903     Bangladesh        India     Colombo            118          19
# 36581  South Africa    Sri Lanka  Hambantota             59          59
# 30272         India      England     Kolkata             83          36
# 2844     Bangladesh    Sri Lanka     Colombo            151          19
# 18639    Bangladesh    Australia   Cape Town             99          27
#
#        wickets_left  current_runrate  last_five  runs_x
# ...

# %% [markdown]
# ## Splitting the Data into training and testing

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %% [markdown]
# ## Training the Model

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_absolute_error
from xgboost import XGBRegressor

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators = 1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9885874494133138
# 1.5938839304974621

# %%
# pickle.dump(pipe,open('pipe.pkl','wb'))
